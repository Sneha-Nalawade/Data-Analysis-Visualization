# %%
# !pip install joypy squarify

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import transforms
from joypy import joyplot
import squarify
import plotly.express as px
from itertools import product

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
milk_data = pd.read_csv("/content/drive/MyDrive/DAV sem 6/Milk_Production_2007_2012.csv")
egg_data = pd.read_csv("/content/drive/MyDrive/DAV sem 6/Egg_Production_2007_2012.csv")
egg_data.columns = ["States/Uts","2007-08", "2008-09", "2009-10","2010-11", "2011-12"]

# %%
milk_data["Food"] = "Milk"

# %%
milk_data.tail()
# Out:
#      States/Uts  2007-08  2008-09  2009-10  2010-11  2011-12  Food
# 31  Daman & Diu        1        1        1        1        1  Milk
# 32        Delhi      445      450      466      480      502  Milk
# 33  Lakshadweep        2        2        2        2        2  Milk
# 34   Puducherry       47       46       46       47       45  Milk
# 35    All India   107934   112183   116425   121848   127904  Milk

# %%
egg_data["Food"] = "Egg"

# %%
egg_data.tail()
# Out:
#      States/Uts  2007-08  2008-09  2009-10  2010-11  2011-12 Food
# 31  Daman & Diu       18       19       19       19       20  Egg
# 32        Delhi        1        1        1        1        1  Egg
# 33  Lakshadweep      128      135      138      138      140  Egg
# 34   Puducherry      137      112      113      114      116  Egg
# 35        Total   535649   555624   602671   630244   664499  Egg

# %%
egg_data.iloc[-1,0] = 'All India'

# %%
egg_data.tail()
# Out:
#      States/Uts  2007-08  2008-09  2009-10  2010-11  2011-12 Food
# 31  Daman & Diu       18       19       19       19       20  Egg
# 32        Delhi        1        1        1        1        1  Egg
# 33  Lakshadweep      128      135      138      138      140  Egg
# 34   Puducherry      137      112      113      114      116  Egg
# 35    All India   535649   555624   602671   630244   664499  Egg

# %%
merged_data = pd.concat([milk_data, egg_data], ignore_index=True)

# %%
merged_data
# Out:
#            States/Uts  2007-08  2008-09  2009-10  2010-11  2011-12  Food
# 0      Andhra Pradesh     8925     9570    10429    11203    12088  Milk
# 1   Arunachal Pradesh       32       24       26       28       22  Milk
# 2               Assam      752      753      756      790      796  Milk
# 3               Bihar     5783     5934     6124     6517     6643  Milk
# 4        Chhattisgarh      866      908      956     1029     1119  Milk
# ..                ...      ...      ...      ...      ...      ...   ...
# 67        Daman & Diu       18       19       19       19       20   Egg
# 68              Delhi        1        1        1        1        1   Egg
# 69        Lakshadweep      128      135      138      138      140   Egg
# 70         Puducherry      137      112      113      114      116   Egg
# 71          All India   535649   555624   602671   630244   664499   Egg
#
# [72 rows x 7 columns]

# %%
final_df = merged_data.groupby(['States/Uts', 'Food']).sum()

# %%
final_df
# Out:
#                                 2007-08  2008-09  2009-10  2010-11  2011-12
# States/Uts                Food
# All India                 Egg    535649   555624   602671   630244   664499
#                           Milk   107934   112183   116425   121848   127904
# Andaman & Nicobar Islands Egg       622      618      657      672      780
#                           Milk       24       26       24       25       26
# Andhra Pradesh            Egg    175884   183446   193958   201277   212103
# ...                                 ...      ...      ...      ...      ...
# Uttar Pradesh             Milk    18861    19537    20203    21031    22556
# Uttarakhand               Egg      1911     1962     2536     2614     2712
#                           Milk     1221     1230     1377     1383     1417
# West Bengal               Egg     30542    33056    36978    39939    43433
#                           Milk     4087     4176     4300     4471     4672
#
# [72 rows x 5 columns]

# %%
print(final_df)
# Out:
#                                 2007-08  2008-09  2009-10  2010-11  2011-12
# States/Uts                Food
# All India                 Egg    535649   555624   602671   630244   664499
#                           Milk   107934   112183   116425   121848   127904
# Andaman & Nicobar Islands Egg       622      618      657      672      780
#                           Milk       24       26       24       25       26
# Andhra Pradesh            Egg    175884   183446   193958   201277   212103
# ...                                 ...      ...      ...      ...      ...
# Uttar Pradesh             Milk    18861    19537    20203    21031    22556
# Uttarakhand               Egg      1911     1962     2536     2614     2712
#                           Milk     1221     1230     1377     1383     1417
# West Bengal               Egg     30542    33056    36978    39939    43433
#                           Milk     4087     4176     4300     4471     4672
#
# [72 rows x 5 columns]

# %%
states_of_interest = [('Haryana','Egg'), ('Bihar','Egg'), ('Uttar Pradesh','Egg'),
('Andhra Pradesh','Egg'), ('Madhya Pradesh','Egg'), ('Haryana','Milk'), ('Bihar','Milk'), ('Uttar Pradesh','Milk'),
('Andhra Pradesh','Milk'), ('Madhya Pradesh','Milk')]

# %%
data_total = final_df.loc[final_df.index.isin(states_of_interest)]
data_total
# Out:
#                      2007-08  2008-09  2009-10  2010-11  2011-12
# States/Uts     Food
# Andhra Pradesh Egg    175884   183446   193958   201277   212103
#                Milk     8925     9570    10429    11203    12088
# Bihar          Egg     10707    10740    11002     7446     7552
#                Milk     5783     5934     6124     6517     6643
# Haryana        Egg     41031    38150    38453    39644    41142
#                Milk     5442     5745     6006     6267     6661
# Madhya Pradesh Egg      9747     6713     7075     7577     7972
#                Milk     6572     6855     7167     7514     8149
# Uttar Pradesh  Egg      9814    10140    10596    10991    16075
#                Milk    18861    19537    20203    21031    22556

# %%
data_2011 = data_total['2011-12']

# %%
data_2011
# Out:
# States/Uts      Food
# Andhra Pradesh  Egg     212103
#                 Milk     12088
# Bihar           Egg       7552
#                 Milk      6643
# Haryana         Egg      41142
#                 Milk      6661
# Madhya Pradesh  Egg       7972
#                 Milk      8149
# Uttar Pradesh   Egg      16075
#                 Milk     22556
# Name: 2011-12, dtype: int64

# %%
dic= data_2011.to_dict()

labelizer = lambda k:dic[k]
props = {}
colors = sns.color_palette("Paired")
i=0
for patch in states_of_interest:
    props[patch] = {'alpha': 0.8, 'color': colors[i]}
    i += 1
mosaic(data_2011,labelizer =labelizer,gap=0.01, title="Year: 2011-12", label_rotation=[80,1],properties=props)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-62a135d3ea05> in <cell line: 10>()
#       8     props[patch] = {'alpha': 0.8, 'color': colors[i]}
#       9     i += 1
# ---> 10 mosaic(data_2011,labelizer =labelizer,gap=0.01, title="Year: 2011-12", label_rotation=[80,1],properties=props)
#      11 plt.show()
#
# NameError: name 'mosaic' is not defined
